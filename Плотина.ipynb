# %%
# %%capture
# !git clone https://github.com/daniluck505/university.git
from university import dam_colab
Dam = dam_colab.DamApp()

# %%
Dam.make_calc()
# Out:
# Высота плотины: 30
# Ширина гребня плотины: 10
# Заложение верхового откоса: 3
# Заложение низового откоса: 3
# Глубина воды в верхнем бьефе: 25
# Глубина воды нижнем бьефе: 3
# Толщина проницаемого слоя основания: 5
